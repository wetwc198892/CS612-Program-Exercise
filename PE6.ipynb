# %%
import pandas as pd

# %%
data = pd.read_csv("sales_data_sample.csv")
data[(data["COUNTRY"] == "USA")].count()['COUNTRY']
# Out:
# 1004

# %%
data = data.dropna(subset=["TERRITORY"])
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 6           10180               29      86.13                9  2497.77
# 7           10188               48     100.00                1  5512.32
# 9           10211               41     100.00               14  4708.44
# ...           ...              ...        ...              ...      ...
# 2816        10327               37      86.74                4  3209.38
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
data[(data["COUNTRY"] == "USA")].count()["COUNTRY"]
# Out:
# 0

# %%
data = data.drop_duplicates(subset='ORDERNUMBER',keep='last')
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 222         10216               43     100.00                1  5759.42
# 327         10231               49     100.00                1  6952.12
# 408         10277               28     100.00                1  3127.88
# 514         10256               29      51.75                1  1500.75
# 820         10298               32      48.46                2  1550.72
# ...           ...              ...        ...              ...      ...
# 2816        10327               37      86.74                4  3209.38
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
data[(data["PRODUCTLINE"] == "Motorcycles")]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 820         10298               32      48.46                2  1550.72
# 1204        10286               38      57.20                1  2173.60
# 1491        10417               35     100.00                3  3550.05
# 1566        10134               43      83.03                7  3570.29
# 1568        10158               22      67.03                1  1474.66
# 1587        10389               49      81.40                2  3988.60
# 1588        10402               59      87.60                3  5168.40
# 1686        10330               42      81.03                1  3403.26
# 2192        10363               50     100.00                2  6576.50
# 2194        10387               44      94.90                1  4175.60
# 2198        10122               31      44.66               17  1384.46
# 2213        10310               36      43.05               17  1549.80
# ...

# %%
qty = data['QUANTITYORDERED']
qty
# Out:
# 222     43
# 327     49
# 408     28
# 514     29
# 820     32
#         ..
# 2816    37
# 2818    20
# 2819    29
# 2820    43
# 2821    34
# Name: QUANTITYORDERED, Length: 188, dtype: int64

# %%
pd.cut(qty,4)
# Out:
# 222       (30.25, 45.5]
# 327       (45.5, 60.75]
# 408     (14.939, 30.25]
# 514     (14.939, 30.25]
# 820       (30.25, 45.5]
#              ...
# 2816      (30.25, 45.5]
# 2818    (14.939, 30.25]
# 2819    (14.939, 30.25]
# 2820      (30.25, 45.5]
# 2821      (30.25, 45.5]
# Name: QUANTITYORDERED, Length: 188, dtype: category
# Categories (4, interval[float64]): [(14.939, 30.25] < (30.25, 45.5] < (45.5, 60.75] < (60.75, 76.0]]

# %%
qty.value_counts(bins=4)
# Out:
# (30.25, 45.5]      92
# (14.938, 30.25]    61
# (45.5, 60.75]      31
# (60.75, 76.0]       4
# Name: QUANTITYORDERED, dtype: int64

# %%
pd.qcut(qty,4)
# Out:
# 222       (37.0, 44.0]
# 327       (44.0, 76.0]
# 408     (14.999, 28.0]
# 514       (28.0, 37.0]
# 820       (28.0, 37.0]
#              ...
# 2816      (28.0, 37.0]
# 2818    (14.999, 28.0]
# 2819      (28.0, 37.0]
# 2820      (37.0, 44.0]
# 2821      (28.0, 37.0]
# Name: QUANTITYORDERED, Length: 188, dtype: category
# Categories (4, interval[float64]): [(14.999, 28.0] < (28.0, 37.0] < (37.0, 44.0] < (44.0, 76.0]]

# %%
pd.qcut(qty,4).value_counts()
# Out:
# (14.999, 28.0]    50
# (37.0, 44.0]      49
# (28.0, 37.0]      46
# (44.0, 76.0]      43
# Name: QUANTITYORDERED, dtype: int64
